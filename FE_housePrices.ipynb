# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

#get path to csv file
house_value_metadata_path = "Resources/County_zhvi_uc_sfrcondo_mon.csv"

# Read the house value file 
house_value_metadata= pd.read_csv(house_value_metadata_path)

house_value_metadata.head()
# Out:
#    RegionID  SizeRank          RegionName RegionType StateName State  \
# 0      3101         0  Los Angeles County     County        CA    CA
# 1       139         1         Cook County     County        IL    IL
# 2      1090         2       Harris County     County        TX    TX
# 3      2402         3     Maricopa County     County        AZ    AZ
# 4      2841         4    San Diego County     County        CA    CA
#
#                               Metro  StateCodeFIPS  MunicipalCodeFIPS  \
# 0    Los Angeles-Long Beach-Anaheim              6                 37
# 1          Chicago-Naperville-Elgin             17                 31
# 2  Houston-The Woodlands-Sugar Land             48                201
# 3           Phoenix-Mesa-Scottsdale              4                 13
# 4                San Diego-Carlsbad              6                 73
#
#    1996-01-31  ...  2020-07-31  2020-08-31  2020-09-30  2020-10-31  \
# ...

# %%
#select only data where state is TX
texas_home_value_data= house_value_metadata[house_value_metadata['State'] == 'TX']

texas_home_value_data
# Out:
#       RegionID  SizeRank          RegionName RegionType StateName State  \
# 2         1090         2       Harris County     County        TX    TX
# 8          978         8       Dallas County     County        TX    TX
# 15        2049        15      Tarrant County     County        TX    TX
# 18         386        18        Bexar County     County        TX    TX
# 38        1440        38       Travis County     County        TX    TX
# ...        ...       ...                 ...        ...       ...   ...
# 2821      3139      2945  Shackelford County     County        TX    TX
# 2822      1353      2946       Reagan County     County        TX    TX
# 2823       174      2948         Hall County     County        TX    TX
# 2825       300      2952         Real County     County        TX    TX
# 2852      2621      3059    Armstrong County     County        TX    TX
#
#                                  Metro  StateCodeFIPS  MunicipalCodeFIPS  \
# ...

# %%
#export to output file 
texas_home_value_data.to_csv('Resources/Zilow_Texas_HomeValues.csv',encoding = 'utf-8',index = False)

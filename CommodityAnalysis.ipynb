# %%
import pandas as pd
import matplotlib.pyplot as pt
from datetime import date
# %matplotlib notebook

# %%
# Path_comm= "Resources/Commodity_Monthly_2005.csv"
# Path_oil="Resources/Oil_Daily_1980.csv"
# Path_housing="Resources/HousingIndex_Quarterly_2005.csv"

# commodity_price_df=pd.read_csv(Path_comm)
# oil_price_df=pd.read_csv(Path_oil)
# Hosuing_Ind_df=pd.read_csv(Path_housing)
# commodity_price_df.head()
# #oil_price_df.head()
# #Hosuing_Ind_df.head(30)

Path_comm_hou="Resources/Commodity_Housing_Quarterly_1995.csv"
comm_hou_df=pd.read_csv(Path_comm_hou)
comm_hou_df.head()
# Out:
#         DATE      Lumber       Steel      Copper    WTI Oil  Hosing Index
# 0   1/1/1995  179.733333  128.233333  149.000000  18.356667        129.49
# 1   4/1/1995  173.000000  129.800000  150.566667  19.343333        131.75
# 2   7/1/1995  173.100000  129.900000  151.500000  17.853333        133.35
# 3  10/1/1995  167.900000  127.300000  150.266667  18.156667        134.18
# 4   1/1/1996  167.366667  126.333333  147.233333  19.770000        135.55

# %%
# analysis_df=commodity_price_df.merge(oil_price_df, on ="DATE",how="outer")
# analysis_df=analysis_df.merge(Hosuing_Ind_df,on="DATE",how="outer")

# analysis_df.head (10)
# # analysis_df.dtypes
# # analysis_df.DATE[0]

# %%
plt.figure(figsize=(20,5))
plt.plot(comm_hou_df["DATE"],comm_hou_df["Lumber"])
plt.xticks(rotation="vertical")
plt.title("Lumber Quart Price from 2005 ")
plt.xlabel("Date")
plt.ylabel("Average Price Quar")



plt.show()
# Out:
# <img src="data:image/png;base64,..." width="2000">

# %%
plt.figure(figsize=(20,5))
plt.xticks(rotation="vertical")
plt.scatter(comm_hou_df["DATE"], comm_hou_df["Lumber"], marker="o", color="red")

# %%
plt.figure(figsize=(20,5))
plt.plot(comm_hou_df["DATE"],comm_hou_df["Steel"])
plt.xticks(rotation="vertical")
plt.title("Steel Quart Price from 2005 ")
plt.xlabel("Date")
plt.ylabel("Average Price Quart")



plt.show()

# %%
plt.figure(figsize=(20,5))
plt.plot(comm_hou_df["DATE"],comm_hou_df["Copper"])
plt.xticks(rotation="vertical")
plt.title("Copper Quart Price from 2005 ")
plt.xlabel("Date")
plt.ylabel("Average Price Quart")



plt.show()

# %%
plt.figure(figsize=(20,5))
plt.plot(comm_hou_df["DATE"],comm_hou_df["WTI Oil"])
plt.xticks(rotation="vertical")
plt.title("WTI oil Quart Price from 2005 ")
plt.xlabel("Date")
plt.ylabel("Average Price Quart")



plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot(comm_hou_df["DATE"],comm_hou_df["Hosing Index"], label="All-Transactions House Price Index for Texas",color= "yellow")
plt.plot(comm_hou_df["DATE"],comm_hou_df["WTI Oil"],label='West Texas Intermediate (WTI), Dollars per Barrel',color= "blue")
plt.plot(comm_hou_df["DATE"],comm_hou_df["Copper"], label="Producer Price Index Copper Wire and Cable",color= "black")
plt.plot(comm_hou_df["DATE"],comm_hou_df["Steel"],label="Producer Price Index Iron and Steel", color= "red")
plt.plot(comm_hou_df["DATE"],comm_hou_df["Lumber"],label= "Producer Price Index Lumber", color= "green")

plt.xticks(rotation="vertical")
plt.title("Housing Index Quart Price from 2005 ")
plt.xlabel("Date")
plt.ylabel("Average Price Quart")


plt.legend(loc="best")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1500">

# %%
# # ax1 = plt.subplot(311)
# # plt.plot(t, s1)
# # plt.setp(ax1.get_xticklabels(), fontsize=6)

# # # share x only
# # ax2 = plt.subplot(312, sharex=ax1)
# # plt.plot(t, s2)
# # # make these tick labels invisible
# # plt.setp(ax2.get_xticklabels(), visible=False)

# ax1=plt.subplot()
# plt.plot(comm_hou_df["DATE"],comm_hou_df["Hosing Index"], label="All-Transactions House Price Index for Texas",color= "yellow")
# plt.setp(ax1.get_xticklabels(), fontsize=6)
# plt.show()
# # ax2=ax2 = plt.subplot( sharex=ax1)
# # plt.plot(comm_hou_df["DATE"],comm_hou_df["WTI Oil"],label='West Texas Intermediate (WTI), Dollars per Barrel',color= "blue")
# # plt.setp(ax2.get_xticklabels(), visible=False)


# # plt.legend(loc="best")

# # plt.show()

# %%
Path_comm_hou_new="Resources/Commodity_Housing_Quarterly_Per_1995.csv"
comm_hou_new_df=pd.read_csv(Path_comm_hou_new)
comm_hou_new_df.head()
# Out:
#         DATE     Metal   WTI oil    Copper  Housing index  Lumber
# 0   1/1/2005  25.59009  40.98516  14.14365        3.50849  6.16617
# 1   4/1/2005   9.61497  38.38595  14.73889        4.15058 -4.18782
# 2   7/1/2005  -4.51186  43.82125  24.91189        4.97194 -8.72930
# 3  10/1/2005  -4.83484  24.27546  48.96962        4.99819 -2.10793
# 4   1/1/2006  -1.37700  27.44099  41.21975        5.69571 -1.47662

# %%
plt.figure(figsize=(15,5))
plt.plot(comm_hou_new_df["DATE"],comm_hou_new_df["Housing index"], label="All-Transactions House Price Index for Texas",color= "yellow")
plt.plot(comm_hou_new_df["DATE"],comm_hou_new_df["WTI oil"],label='West Texas Intermediate (WTI), Dollars per Barrel',color= "blue")
plt.plot(comm_hou_new_df["DATE"],comm_hou_new_df["Copper"], label="Producer Price Index Copper Wire and Cable",color= "black")
plt.plot(comm_hou_new_df["DATE"],comm_hou_new_df["Metal"],label="Producer Price Index Iron and Steel", color= "red")
#plt.plot(comm_hou_new_df["DATE"],comm_hou_new_df["Lumber"],label= "Producer Price Index Lumber", color= "green")

plt.xticks(rotation="vertical")
plt.title("Indexes Quart Price from 2005 ")
plt.xlabel("Date")
plt.ylabel("Average Price Quart")


plt.legend(loc="best")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1500">
